# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import random
import tensorflow as tf
import matplotlib.pyplot as plt
import os

# %%
X_train = np.load('/home/iotadmin/notebooks/array/window_50_t_train_split_small.npy')

# %%
Y_train = np.load('/home/iotadmin/notebooks/array/window_50_t_train_split_small1.npy')

# %%
X_test = np.load('/home/iotadmin/notebooks/array/test_window_50_t_test_split_small.npy')

# %%
Y_test = np.load('/home/iotadmin/notebooks/array/test_window_50_t_test_split_small1.npy')

# %%
X_train = np.load('/home/iotadmin/notebooks/array/window_200_t.npy')

# %%
Y_train1 = np.load('/home/iotadmin/notebooks/array/window_200_t_1.npy')
Y_train2 = np.load('/home/iotadmin/notebooks/array/window_200_t_2.npy')
Y_train3 = np.load('/home/iotadmin/notebooks/array/window_200_t_3.npy')
Y_train4 = np.load('/home/iotadmin/notebooks/array/window_200_t_4.npy')
Y_train5 = np.load('/home/iotadmin/notebooks/array/window_200_t_5.npy')
Y_train6 = np.load('/home/iotadmin/notebooks/array/window_200_t_6.npy')
Y_train7 = np.load('/home/iotadmin/notebooks/array/window_200_t_7.npy')
Y_train8 = np.load('/home/iotadmin/notebooks/array/window_200_t_8.npy')
Y_train9 = np.load('/home/iotadmin/notebooks/array/window_200_t_9.npy')
Y_train10 = np.load('/home/iotadmin/notebooks/array/window_200_t_10.npy')
Y_train11 = np.load('/home/iotadmin/notebooks/array/window_200_t_11.npy')
Y_train12 = np.load('/home/iotadmin/notebooks/array/window_200_t_12.npy')
Y_train13 = np.load('/home/iotadmin/notebooks/array/window_200_t_13.npy')
Y_train14 = np.load('/home/iotadmin/notebooks/array/window_200_t_14.npy')
Y_train15 = np.load('/home/iotadmin/notebooks/array/window_200_t_15.npy')
Y_train16 = np.load('/home/iotadmin/notebooks/array/window_200_t_16.npy')
Y_train17 = np.load('/home/iotadmin/notebooks/array/window_200_t_17.npy')
Y_train18 = np.load('/home/iotadmin/notebooks/array/window_200_t_18.npy')
Y_train19 = np.load('/home/iotadmin/notebooks/array/window_200_t_19.npy')
Y_train20 = np.load('/home/iotadmin/notebooks/array/window_200_t_20.npy')
Y_train21 = np.load('/home/iotadmin/notebooks/array/window_200_t_21.npy')
Y_train22 = np.load('/home/iotadmin/notebooks/array/window_200_t_22.npy')
Y_train23 = np.load('/home/iotadmin/notebooks/array/window_200_t_23.npy')
Y_train24 = np.load('/home/iotadmin/notebooks/array/window_200_t_24.npy')

# %%
X_test = np.load('/home/iotadmin/notebooks/array/test_window_200_s.npy')

# %%
Y_test = np.load('/home/iotadmin/notebooks/array/test_window_200_t_11.npy')
Y_test1 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_1.npy')
Y_test2 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_2.npy')
Y_test3 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_3.npy')
Y_test4 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_4.npy')
Y_test5 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_5.npy')
Y_test6 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_6.npy')
Y_test7 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_7.npy')
Y_test8 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_8.npy')
Y_test9 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_9.npy')
Y_test10 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_10.npy')
Y_test11 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_11.npy')
Y_test12 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_12.npy')
Y_test13 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_13.npy')
Y_test14 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_14.npy')
Y_test15 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_15.npy')
Y_test16 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_16.npy')
Y_test17 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_17.npy')
Y_test18 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_18.npy')
Y_test19 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_19.npy')
Y_test20 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_20.npy')
Y_test21 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_21.npy')
Y_test22 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_22.npy')
Y_test23 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_23.npy')
Y_test24 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_24.npy')

# %%
from tensorflow.keras.layers import LSTM, RNN, Input, Dense,Conv1D,MaxPooling1D,Flatten,BatchNormalization,Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Bidirectional

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import load_model

step = 200
n_inputs = 42
n_hiddens = 64
n_outputs = 1

inputs = Input(shape=(step, n_inputs))
x = Conv1D(256, 10, activation='relu')(inputs)
x = MaxPooling1D(5)(x)
x = Flatten()(x)
x = Dense(32,activation='relu')(x)
output = Dense(n_outputs)(x)
model = Model(inputs,output)
model.compile(optimizer='adam', loss='mse',metrics=['mae'])
history = model.fit(X_train, Y_train1, epochs= 200, batch_size=128)
model.save("home/iotadmin/notebooks/model/each_23.h5")
Y_predict = model.predict(X_test)
Y_predict=Y_predict.reshape(Y_predict.shape[0],)
print((np.corrcoef([Y_test1,Y_predict])[0][1])**2)
submit = pd.DataFrame({"label":Y_test,"pred":Y_predict})
submit.to_csv('/home/iotadmin/notebooks/csv/each_23.csv', index = False)
# Out:
# Train on 193115 samples
# Epoch 1/200
# 193115/193115 [==============================] - 11s 57us/sample - loss: 144844.4343 - mae: 245.7170
# Epoch 2/200
# 193115/193115 [==============================] - 10s 50us/sample - loss: 83020.9571 - mae: 172.2908
# Epoch 3/200
# 193115/193115 [==============================] - 10s 50us/sample - loss: 76375.7155 - mae: 160.6109
# Epoch 4/200
# 193115/193115 [==============================] - 10s 50us/sample - loss: 72984.1850 - mae: 155.2030
# Epoch 5/200
# 193115/193115 [==============================] - 10s 50us/sample - loss: 70798.5855 - mae: 151.0334
# Epoch 6/200
# 170240/193115 [=========================>....] - ETA: 1s - loss: 70027.1052 - mae: 149.8217
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-a3abec5552b6> in <module>
#      16 model = Model(inputs,output)
#      17 model.compile(optimizer='adam', loss='mse',metrics=['mae'])
# ---> 18 history = model.fit(X_train, Y_train1, epochs= 200, batch_size=128)
#      19 model.save("home/iotadmin/notebooks/model/each_23.h5")
#      20 Y_predict = model.predict(X_test)
#
# /anaconda/envs/azureml_py36_tensorflow/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# /anaconda/envs/azureml_py36_tensorflow/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     340                 mode=ModeKeys.TRAIN,
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     344
#
# /anaconda/envs/azureml_py36_tensorflow/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     179             batch_end=step * batch_size + current_batch_size)
#     180       cbks.make_logs(model, batch_logs, batch_outs, mode)
# --> 181       step += 1
#     182
#     183     if callbacks.model.stop_training:
#
# /anaconda/envs/azureml_py36_tensorflow/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      86         if type is None:
#      87             try:
# ---> 88                 next(self.gen)
#      89             except StopIteration:
#      90                 return False
#
# /anaconda/envs/azureml_py36_tensorflow/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/training_v2.py in on_batch(self, step, mode, size)
#     787           self.callbacks._call_batch_hook(
#     788               mode, 'end', step, batch_logs)
# --> 789           self.progbar.on_batch_end(step, batch_logs)
#
# /anaconda/envs/azureml_py36_tensorflow/lib/python3.6/site-packages/tensorflow_core/python/keras/callbacks.py in on_batch_end(self, batch, logs)
#     779     # will be handled by on_epoch_end.
#     780     if self.verbose and (self.target is None or self.seen < self.target):
# --> 781       self.progbar.update(self.seen, self.log_values)
#     782
#     783   def on_epoch_end(self, epoch, logs=None):
#
# /anaconda/envs/azureml_py36_tensorflow/lib/python3.6/site-packages/tensorflow_core/python/keras/utils/generic_utils.py in update(self, current, values)
#     506       prev_total_width = self._total_width
#     507       if self._dynamic_display:
# --> 508         sys.stdout.write('\b' * prev_total_width)
#     509         sys.stdout.write('\r')
#     510       else:
#
# /anaconda/envs/azureml_py36_tensorflow/lib/python3.6/site-packages/ipykernel/iostream.py in write(self, string)
#     408                     self.flush()
#     409             else:
# --> 410                 self._schedule_flush()
#     411
#     412     def writelines(self, sequence):
#
# /anaconda/envs/azureml_py36_tensorflow/lib/python3.6/site-packages/ipykernel/iostream.py in _schedule_flush(self)
#     332         def _schedule_in_thread():
#     333             self._io_loop.call_later(self.flush_interval, self._flush)
# --> 334         self.pub_thread.schedule(_schedule_in_thread)
#     335
#     336     def flush(self):
#
# /anaconda/envs/azureml_py36_tensorflow/lib/python3.6/site-packages/ipykernel/iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# /anaconda/envs/azureml_py36_tensorflow/lib/python3.6/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     398                                  copy_threshold=self.copy_threshold)
#     399             data.group = group
# --> 400         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     401
#     402     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /anaconda/envs/azureml_py36_tensorflow/lib/python3.6/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
from tensorflow.keras.models import load_model
model = load_model("home/iotadmin/notebooks/model/each_23.h5")
Y_predict = model.predict(X_test)
Y_predict=Y_predict.reshape(Y_predict.shape[0],)
print((np.corrcoef([Y_test23,Y_predict])[0][1])**2)
# Out:
# 0.0011962606175553413

# %%
r2_csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-500cbb4c6322> in <module>
# ----> 1 r2_csv
#
# NameError: name 'r2_csv' is not defined

# %%
submit = pd.DataFrame(r2_csv)
submit.to_csv('/home/iotadmin/notebooks/csv/each_r2.csv' % i+1, index = False)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
Y_predict = model.predict(X_test)
print(mean_squared_error(Y_test, Y_predict))
print(mean_squared_error(Y_test, Y_predict)**0.5)
print(r2_score(Y_test, Y_predict))
# Out:
# 47012.079941739226
# 216.82269240496768
# -0.5374851063919115

# %%
import matplotlib.pyplot as plt 

plt.figure(figsize=(40, 20))

#plt.plot(b.iloc[:500])
plt.plot(Y_predict[0:2000],marker='o',linestyle='solid',label='a')
plt.plot(Y_test[0:2000],marker='o',linestyle='solid',label='b')
#plt.plot(select.iloc[:500])
plt.legend(loc='upper right')
plt.show()

# %%
submit = pd.DataFrame(Y_predict)

# %%
submit.to_csv('/home/iotadmin/notebooks/csv/FLMY.csv', index = False)
