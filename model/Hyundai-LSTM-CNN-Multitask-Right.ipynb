# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import random
import tensorflow as tf
import matplotlib.pyplot as plt
import os

# %%
X_train = np.load('/home/iotadmin/notebooks/array/window_200_t.npy')

# %%
Y_train1 = np.load('/home/iotadmin/notebooks/array/window_200_t_1.npy')
Y_train2 = np.load('/home/iotadmin/notebooks/array/window_200_t_2.npy')
Y_train3 = np.load('/home/iotadmin/notebooks/array/window_200_t_3.npy')
Y_train4 = np.load('/home/iotadmin/notebooks/array/window_200_t_4.npy')
Y_train5 = np.load('/home/iotadmin/notebooks/array/window_200_t_5.npy')
Y_train6 = np.load('/home/iotadmin/notebooks/array/window_200_t_6.npy')
Y_train7 = np.load('/home/iotadmin/notebooks/array/window_200_t_7.npy')
Y_train8 = np.load('/home/iotadmin/notebooks/array/window_200_t_8.npy')
Y_train9 = np.load('/home/iotadmin/notebooks/array/window_200_t_9.npy')
Y_train10 = np.load('/home/iotadmin/notebooks/array/window_200_t_10.npy')
Y_train11 = np.load('/home/iotadmin/notebooks/array/window_200_t_11.npy')
Y_train12 = np.load('/home/iotadmin/notebooks/array/window_200_t_12.npy')
Y_train13 = np.load('/home/iotadmin/notebooks/array/window_200_t_13.npy')
Y_train14 = np.load('/home/iotadmin/notebooks/array/window_200_t_14.npy')
Y_train15 = np.load('/home/iotadmin/notebooks/array/window_200_t_15.npy')
Y_train16 = np.load('/home/iotadmin/notebooks/array/window_200_t_16.npy')
Y_train17 = np.load('/home/iotadmin/notebooks/array/window_200_t_17.npy')
Y_train18 = np.load('/home/iotadmin/notebooks/array/window_200_t_18.npy')
Y_train19 = np.load('/home/iotadmin/notebooks/array/window_200_t_19.npy')
Y_train20 = np.load('/home/iotadmin/notebooks/array/window_200_t_20.npy')
Y_train21 = np.load('/home/iotadmin/notebooks/array/window_200_t_21.npy')
Y_train22 = np.load('/home/iotadmin/notebooks/array/window_200_t_22.npy')
Y_train23 = np.load('/home/iotadmin/notebooks/array/window_200_t_23.npy')
Y_train24 = np.load('/home/iotadmin/notebooks/array/window_200_t_24.npy')

# %%
X_test = np.load('/home/iotadmin/notebooks/array/test_window_200_s.npy')

# %%
Y_test1 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_1.npy')
Y_test2 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_2.npy')
Y_test3 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_3.npy')
Y_test4 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_4.npy')
Y_test5 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_5.npy')
Y_test6 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_6.npy')
Y_test7 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_7.npy')
Y_test8 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_8.npy')
Y_test9 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_9.npy')
Y_test10 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_10.npy')
Y_test11 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_11.npy')
Y_test12 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_12.npy')
Y_test13 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_13.npy')
Y_test14 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_14.npy')
Y_test15 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_15.npy')
Y_test16 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_16.npy')
Y_test17 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_17.npy')
Y_test18 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_18.npy')
Y_test19 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_19.npy')
Y_test20 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_20.npy')
Y_test21 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_21.npy')
Y_test22 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_22.npy')
Y_test23 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_23.npy')
Y_test24 = np.load('/home/iotadmin/notebooks/array/test_window_200_t_24.npy')

# %%
from tensorflow.keras.layers import LSTM, RNN, Input, Dense,Conv1D,MaxPooling1D,Flatten,BatchNormalization
from tensorflow.keras.models import Model

step = 200
n_inputs = 42
n_hiddens = 64
n_outputs = 1
inputs = Input(shape=(step, n_inputs))
x = Conv1D(256, 10, activation='relu')(inputs)
x = MaxPooling1D(5)(x)
x = Flatten()(x)
x = Dense(32,activation='relu')(x)

'''
## Left
output1 = Dense(n_outputs)(x)
output2 = Dense(n_outputs)(x)
output3 = Dense(n_outputs)(x)
output4 = Dense(n_outputs)(x)
output5 = Dense(n_outputs)(x)
output6 = Dense(n_outputs)(x)
output13 = Dense(n_outputs)(x)
output14 = Dense(n_outputs)(x)
output15 = Dense(n_outputs)(x)
output16 = Dense(n_outputs)(x)
output17 = Dense(n_outputs)(x)
output18 = Dense(n_outputs)(x)
'''


##Right
output7 = Dense(n_outputs)(x)
output8 = Dense(n_outputs)(x)
output9 = Dense(n_outputs)(x)
output10 = Dense(n_outputs)(x)
output11 = Dense(n_outputs)(x)
output12 = Dense(n_outputs)(x)
output19 = Dense(n_outputs)(x)
output20 = Dense(n_outputs)(x)
output21 = Dense(n_outputs)(x)
output22 = Dense(n_outputs)(x)
output23 = Dense(n_outputs)(x)
output24 = Dense(n_outputs)(x)


#model = Model(inputs,[output1,output2,output3,output4,output5,output6,output7,output8,output9,output10,output11,output12,output13,output14,output15,output16,output17,output18,output19,output20,output21,output22,output23,output24])
model = Model(inputs,[output7,output8,output9,output10,output11,output12,
                      output19,output20,output21,output22,output23,output24])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 200, 42)]    0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 191, 256)     107776      input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 38, 256)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 9728)         0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           311328      flatten[0][0]
# ...

# %%
model.compile(optimizer='adam', loss='mse',metrics=['mae'])
#history = model.fit(X_train,[Y_train1,Y_train2,Y_train3,Y_train4,Y_train5,Y_train6,Y_train7,Y_train8,Y_train9,Y_train10,Y_train11,Y_train12,Y_train13,Y_train14,Y_train15,Y_train16,Y_train17,Y_train18,Y_train19,Y_train20,Y_train21,Y_train22,Y_train23,Y_train24], epochs= 200, batch_size=128)
history = model.fit(X_train,[Y_train7,Y_train8,Y_train9,Y_train10,Y_train11,Y_train12,
                             Y_train19,Y_train20,Y_train21,Y_train22,Y_train23,Y_train24], epochs= 200, batch_size=128)

model.save("home/iotadmin/notebooks/model/Right_multitask.h5")
# Out:
# Train on 193115 samples
# Epoch 1/200
# 193115/193115 [==============================] - 25s 128us/sample - loss: 1963728.9135 - dense_1_loss: 122792.7188 - dense_2_loss: 71907.7344 - dense_3_loss: 1053644.6250 - dense_4_loss: 39279.4531 - dense_5_loss: 21064.5957 - dense_6_loss: 8113.4663 - dense_7_loss: 29628.7812 - dense_8_loss: 34474.6523 - dense_9_loss: 540436.1250 - dense_10_loss: 17746.9258 - dense_11_loss: 20108.2207 - dense_12_loss: 4319.2261 - dense_1_mae: 242.4704 - dense_2_mae: 172.0841 - dense_3_mae: 662.8145 - dense_4_mae: 129.2559 - dense_5_mae: 97.4537 - dense_6_mae: 60.4050 - dense_7_mae: 112.5310 - dense_8_mae: 126.7354 - dense_9_mae: 486.3723 - dense_10_mae: 87.8288 - dense_11_mae: 64.3420 - dense_12_mae: 42.1645
# Epoch 2/200
# ...

# %%
from tensorflow.keras.models import load_model
model = load_model("home/iotadmin/notebooks/model/Right_multitask.h5")

# %%
#Y_predict1,Y_predict2,Y_predict3,Y_predict4,Y_predict5,Y_predict6,Y_predict7,Y_predict8,Y_predict9,Y_predict10,Y_predict11,Y_predict12,Y_predict13,Y_predict14,Y_predict15,Y_predict16,Y_predict17,Y_predict18,Y_predict19,Y_predict20,Y_predict21,Y_predict22,Y_predict23,Y_predict24 = model.predict(X_train)
Y_predict7,Y_predict8,Y_predict9,Y_predict10,Y_predict11,Y_predict12,Y_predict19,Y_predict20,Y_predict21,Y_predict22,Y_predict23,Y_predict24 = model.predict(X_test)
'''
Y_predict1 =Y_predict1.reshape(Y_predict1.shape[0],)
Y_predict2 =Y_predict2.reshape(Y_predict2.shape[0],)
Y_predict3 =Y_predict3.reshape(Y_predict3.shape[0],)
Y_predict4 =Y_predict4.reshape(Y_predict4.shape[0],)
Y_predict5 =Y_predict5.reshape(Y_predict5.shape[0],)
Y_predict6 =Y_predict6.reshape(Y_predict6.shape[0],)
'''

Y_predict7 =Y_predict7.reshape(Y_predict7.shape[0],)
Y_predict8 =Y_predict8.reshape(Y_predict8.shape[0],)
Y_predict9 =Y_predict9.reshape(Y_predict9.shape[0],)
Y_predict10 =Y_predict10.reshape(Y_predict10.shape[0],)
Y_predict11 =Y_predict11.reshape(Y_predict11.shape[0],)
Y_predict12 =Y_predict12.reshape(Y_predict12.shape[0],)

'''
Y_predict13 =Y_predict13.reshape(Y_predict13.shape[0],)
Y_predict14 =Y_predict14.reshape(Y_predict14.shape[0],)
Y_predict15 =Y_predict15.reshape(Y_predict15.shape[0],)
Y_predict16 =Y_predict16.reshape(Y_predict16.shape[0],)
Y_predict17 =Y_predict17.reshape(Y_predict17.shape[0],)
Y_predict18 =Y_predict18.reshape(Y_predict18.shape[0],)
'''
Y_predict19 =Y_predict19.reshape(Y_predict19.shape[0],)
Y_predict20 =Y_predict20.reshape(Y_predict20.shape[0],)
Y_predict21 =Y_predict21.reshape(Y_predict21.shape[0],)
Y_predict22 =Y_predict22.reshape(Y_predict22.shape[0],)
Y_predict23 =Y_predict23.reshape(Y_predict23.shape[0],)
Y_predict24 =Y_predict24.reshape(Y_predict24.shape[0],)

# %%
'''
print((np.corrcoef([Y_train1,Y_predict1])[0][1])**2)
print((np.corrcoef([Y_train2,Y_predict2])[0][1])**2)
print((np.corrcoef([Y_train3,Y_predict3])[0][1])**2)
print((np.corrcoef([Y_train4,Y_predict4])[0][1])**2)
print((np.corrcoef([Y_train5,Y_predict5])[0][1])**2)
print((np.corrcoef([Y_train6,Y_predict6])[0][1])**2)
'''
print((np.corrcoef([Y_train7,Y_predict7])[0][1])**2)
print((np.corrcoef([Y_train8,Y_predict8])[0][1])**2)
print((np.corrcoef([Y_train9,Y_predict9])[0][1])**2)
print((np.corrcoef([Y_train10,Y_predict10])[0][1])**2)
print((np.corrcoef([Y_train11,Y_predict11])[0][1])**2)
print((np.corrcoef([Y_train12,Y_predict12])[0][1])**2)
'''
print((np.corrcoef([Y_train13,Y_predict13])[0][1])**2)
print((np.corrcoef([Y_train14,Y_predict14])[0][1])**2)
print((np.corrcoef([Y_train15,Y_predict15])[0][1])**2)
print((np.corrcoef([Y_train16,Y_predict16])[0][1])**2)
print((np.corrcoef([Y_train17,Y_predict17])[0][1])**2)
print((np.corrcoef([Y_train18,Y_predict18])[0][1])**2)
'''
print((np.corrcoef([Y_train19,Y_predict19])[0][1])**2)
print((np.corrcoef([Y_train20,Y_predict20])[0][1])**2)
print((np.corrcoef([Y_train21,Y_predict21])[0][1])**2)
print((np.corrcoef([Y_train22,Y_predict22])[0][1])**2)
print((np.corrcoef([Y_train23,Y_predict23])[0][1])**2)
print((np.corrcoef([Y_train24,Y_predict24])[0][1])**2)

# %%
#submit = pd.DataFrame({"FLFX":Y_train1,"FLFX_pred":Y_predict1,"FLFY":Y_train2,"FLFY_pred":Y_predict2,"FLFZ":Y_train3,"FLFZ_pred":Y_predict3,"FLMX":Y_train4,"FLMX_pred":Y_predict4,"FLMY":Y_train5,"FLMY_pred":Y_predict5,"FLMZ":Y_train6,"FLMZ_pred":Y_predict6,"FRFX":Y_train7,"FRFX_pred":Y_predict7,"FRFY":Y_train8,"FRFY_pred":Y_predict8,"FRFZ":Y_train9,"FRFZ_pred":Y_predict9,"FRMX":Y_train10,"FRMX_pred":Y_predict10,"FRMY":Y_train11,"FRMY_pred":Y_predict11,"FRMZ":Y_train12,"FRMZ_pred":Y_predict12,"RLFX":Y_train13,"RLFX_pred":Y_predict13,"RLFY":Y_train14,"RLFY_pred":Y_predict14,"RLFZ":Y_train15,"RLFZ_pred":Y_predict15,"RLMX":Y_train16,"RLMX_pred":Y_predict16,"RLMY":Y_train17,"RLMY_pred":Y_predict17,"RLMZ":Y_train18,"RLMZ_pred":Y_predict18,"RRFX":Y_train19,"RRFX_pred":Y_predict19,"RRFY":Y_train20,"RRFY_pred":Y_predict20,"RRFZ":Y_train21,"RRFZ_pred":Y_predict21,"RRMX":Y_train22,"RRMX_pred":Y_predict22,"RRMY":Y_train23,"RRMY_pred":Y_predict23,"RRMZ":Y_train24,"RRMZ_pred":Y_predict24})
'''
submit = pd.DataFrame({"FLFX":Y_train1,"FLFX_pred":Y_predict1,"FLFY":Y_train2,"FLFY_pred":Y_predict2,"FLFZ":Y_train3,"FLFZ_pred":Y_predict3,"FLMX":Y_train4,"FLMX_pred":Y_predict4,"FLMY":Y_train5,"FLMY_pred":Y_predict5,"FLMZ":Y_train6,"FLMZ_pred":Y_predict6,
                       "FRFX":Y_train7,"FRFX_pred":Y_predict7,"FRFY":Y_train8,"FRFY_pred":Y_predict8,"FRFZ":Y_train9,"FRFZ_pred":Y_predict9,"FRMX":Y_train10,"FRMX_pred":Y_predict10,"FRMY":Y_train11,"FRMY_pred":Y_predict11,"FRMZ":Y_train12,"FRMZ_pred":Y_predict12,
                       "RLFX":Y_train13,"RLFX_pred":Y_predict13,"RLFY":Y_train14,"RLFY_pred":Y_predict14,"RLFZ":Y_train15,"RLFZ_pred":Y_predict15,"RLMX":Y_train16,"RLMX_pred":Y_predict16,"RLMY":Y_train17,"RLMY_pred":Y_predict17,"RLMZ":Y_train18,"RLMZ_pred":Y_predict18,
                       "RRFX":Y_train19,"RRFX_pred":Y_predict19,"RRFY":Y_train20,"RRFY_pred":Y_predict20,"RRFZ":Y_train21,"RRFZ_pred":Y_predict21,"RRMX":Y_train22,"RRMX_pred":Y_predict22,"RRMY":Y_train23,"RRMY_pred":Y_predict23,"RRMZ":Y_train24,"RRMZ_pred":Y_predict24})

'''
submit = pd.DataFrame({"FRFX":Y_train7,"FRFX_pred":Y_predict7,"FRFY":Y_train8,"FRFY_pred":Y_predict8,"FRFZ":Y_train9,"FRFZ_pred":Y_predict9,"FRMX":Y_train10,"FRMX_pred":Y_predict10,"FRMY":Y_train11,"FRMY_pred":Y_predict11,"FRMZ":Y_train12,"FRMZ_pred":Y_predict12,
                       "RRFX":Y_train19,"RRFX_pred":Y_predict19,"RRFY":Y_train20,"RRFY_pred":Y_predict20,"RRFZ":Y_train21,"RRFZ_pred":Y_predict21,"RRMX":Y_train22,"RRMX_pred":Y_predict22,"RRMY":Y_train23,"RRMY_pred":Y_predict23,"RRMZ":Y_train24,"RRMZ_pred":Y_predict24})

submit.to_csv('/home/iotadmin/notebooks/csv/Right_multitask_train.csv', index = False)

# %%
import matplotlib.pyplot as plt 

plt.figure(figsize=(40, 20))

#plt.plot(b.iloc[:500])
plt.plot(Y_predict5[0:2000],marker='o',linestyle='solid',label='a')
plt.plot(Y_test5[0:2000],marker='o',linestyle='solid',label='b')
#plt.plot(select.iloc[:500])
plt.legend(loc='upper right')
plt.show()

# %%
plt.figure(figsize=(40, 20))
plt.plot(X_train,linestyle='solid',label='b')
plt.legend(loc='upper right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-adde3ccd7789> in <module>
#       1 plt.figure(figsize=(40, 20))
# ----> 2 plt.plot(X_train,linestyle='solid',label='b')
#       3 plt.legend(loc='upper right')
#       4 plt.show()
#
# /anaconda/envs/azureml_py36_tensorflow/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# /anaconda/envs/azureml_py36_tensorflow/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# ...

# %%
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(patience = 10)
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-89-5c03b283ea42> in <module>
# ----> 1 from keras.callbacks import EarlyStopping
#       2 early_stopping = EarlyStopping(patience = 10)
#
# /anaconda/envs/azureml_py36_tensorflow/lib/python3.6/site-packages/keras/__init__.py in <module>
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# /anaconda/envs/azureml_py36_tensorflow/lib/python3.6/site-packages/keras/utils/__init__.py in <module>
#       4 from . import data_utils
#       5 from . import io_utils
# ----> 6 from . import conv_utils
#       7 from . import losses_utils
#       8 from . import metrics_utils
#
# /anaconda/envs/azureml_py36_tensorflow/lib/python3.6/site-packages/keras/utils/conv_utils.py in <module>
# ...

# %%
X_test.shape
# Out:
# (790877, 50, 42)
